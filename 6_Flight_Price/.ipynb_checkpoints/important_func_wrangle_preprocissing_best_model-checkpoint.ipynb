# %%
import pandas as pd
import numpy as np
import plotly.express as px
# import matplotlib.
# Out:
# C:\Users\Ahmed_Moataz\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_excel("Data_Train.xlsx")

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.nunique()
# Out:
# Airline              12
# Date_of_Journey      44
# Source                5
# Destination           6
# Route               128
# Dep_Time            222
# Arrival_Time       1343
# Duration            368
# Total_Stops           5
# Additional_Info      10
# Price              1870
# dtype: int64

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df["Arrival_Time"].str.split(" ", expand = True)[0].to_datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 df["Arrival_Time"].str.split(" ", expand = True)[0].to_datetime()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_datetime'

# %%
df["Arrival_Time_hour"] = df["Arrival_Time"].str.split(" ", expand = True)[0]

# %%
df["Arrival_Time_hour"] = pd.to_datetime(df["Arrival_Time"]).dt.time

# %%
df.drop(columns= ["Arrival_Time"], inplace = True)

# %%
df.head(10)
# Out:
#              Airline Date_of_Journey    Source Destination  \
# 0             IndiGo      24/03/2019  Banglore   New Delhi
# 1          Air India       1/05/2019   Kolkata    Banglore
# 2        Jet Airways       9/06/2019     Delhi      Cochin
# 3             IndiGo      12/05/2019   Kolkata    Banglore
# 4             IndiGo      01/03/2019  Banglore   New Delhi
# 5           SpiceJet      24/06/2019   Kolkata    Banglore
# 6        Jet Airways      12/03/2019  Banglore   New Delhi
# 7        Jet Airways      01/03/2019  Banglore   New Delhi
# 8        Jet Airways      12/03/2019  Banglore   New Delhi
# 9  Multiple carriers      27/05/2019     Delhi      Cochin
#
#                    Route Dep_Time Duration Total_Stops  \
# 0              BLR → DEL    22:20   2h 50m    non-stop
# 1  CCU → IXR → BBI → BLR    05:50   7h 25m     2 stops
# 2  DEL → LKO → BOM → COK    09:25      19h     2 stops
# 3        CCU → NAG → BLR    18:05   5h 25m      1 stop
# ...

# %%
df["Duration"].str.extractall('(\d+)')
# Out:
#               0
#       match
# 0     0       2
#       1      50
# 1     0       7
#       1      25
# 2     0      19
# ...          ..
# 10680 0       3
# 10681 0       2
#       1      40
# 10682 0       8
#       1      20
#
# [20332 rows x 1 columns]

# %%
df["Duration"].str.split(" ",expand = True)[0].str[:-1]
# Out:
# 0         2
# 1         7
# 2        19
# 3         5
# 4         4
#          ..
# 10678     2
# 10679     2
# 10680     3
# 10681     2
# 10682     8
# Name: 0, Length: 10682, dtype: object

# %%
df["Duration"].str.split(" ",expand = True)[0].str.extractall('(\d+)')
# Out:
#               0
#       match
# 0     0       2
# 1     0       7
# 2     0      19
# 3     0       5
# 4     0       4
# ...          ..
# 10678 0       2
# 10679 0       2
# 10680 0       3
# 10681 0       2
# 10682 0       8
#
# [10682 rows x 1 columns]

# %%
df['hours'] = df["Duration"].str.split(" ",expand = True,)[0].str[:-1]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration Total_Stops Additional_Info  Price Arrival_Time_hour hours
# 0    22:20   2h 50m    non-stop         No info   3897          01:10:00     2
# 1    05:50   7h 25m     2 stops         No info   7662          13:15:00     7
# 2    09:25      19h     2 stops         No info  13882          04:25:00    19
# 3    18:05   5h 25m      1 stop         No info   6218          23:30:00     5
# 4    16:50   4h 45m      1 stop         No info  13302          21:35:00     4

# %%
df["min"] = df["Duration"].str.split(" ",expand = True)[1].str[:-1]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration Total_Stops Additional_Info  Price Arrival_Time_hour  \
# 0    22:20   2h 50m    non-stop         No info   3897          01:10:00
# 1    05:50   7h 25m     2 stops         No info   7662          13:15:00
# 2    09:25      19h     2 stops         No info  13882          04:25:00
# 3    18:05   5h 25m      1 stop         No info   6218          23:30:00
# 4    16:50   4h 45m      1 stop         No info  13302          21:35:00
#
#   hours   min
# 0     2    50
# 1     7    25
# 2    19  None
# ...

# %%
df[df['min'] == 'None']
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Duration, Total_Stops, Additional_Info, Price, Arrival_Time_hour, hours, min]
# Index: []

# %%
df['Duration'].str.split('h|m', expand=True).iloc[:, :-1]
# Out:
#         0    1
# 0       2   50
# 1       7   25
# 2      19
# 3       5   25
# 4       4   45
# ...    ..  ...
# 10678   2   30
# 10679   2   35
# 10680   3
# 10681   2   40
# 10682   8   20
#
# [10682 rows x 2 columns]

# %%
df[['hours', 'minutes']] = df['Duration'].str.split('h|m', expand=True).iloc[:, :-1]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Duration Total_Stops Additional_Info  Price Arrival_Time_hour  \
# 0    22:20   2h 50m    non-stop         No info   3897          01:10:00
# 1    05:50   7h 25m     2 stops         No info   7662          13:15:00
# 2    09:25      19h     2 stops         No info  13882          04:25:00
# 3    18:05   5h 25m      1 stop         No info   6218          23:30:00
# 4    16:50   4h 45m      1 stop         No info  13302          21:35:00
#
#   hours   min minutes
# 0     2    50      50
# 1     7    25      25
# ...

# %%
df['hour'] = df.apply(lambda x: x['hours'] + (x['minutes'] / 60 if x['minutes'] != '' else 0 ), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 df['hour'] = df.apply(lambda x: x['hours'] + (x['minutes'] / 60 if x['minutes'] != '' else 0 ), axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9555, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9544 from pandas.core.apply import frame_apply
#    9546 op = frame_apply(
#    9547     self,
#    9548     func=func,
#    (...)
#    9553     kwargs=kwargs,
#    9554 )
# -> 9555 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:873, in FrameApply.apply_standard(self)
# ...

# %%
df['minutes'] = pd.to_numeric(df['minutes'], errors='coerce')

# %%
df.isna().sum()
# Out:
# Airline                 0
# Date_of_Journey         0
# Source                  0
# Destination             0
# Route                   0
# Dep_Time                0
# Duration                0
# Total_Stops             0
# Additional_Info         0
# Price                   0
# Arrival_Time_hour       0
# hours                   0
# min                  1032
# minutes                 0
# dtype: int64

# %%
df["hours"] = df["hours"].astype(int)

# %%
# fill NaN values with 0
# df['minutes'].fillna(0, inplace=True)

# combine hours and minutes into a single column
df['hour'] = df.apply(lambda x: x['hours'] + x['minutes'] / 60, axis=1)

# drop original columns
df.drop(['hours', 'minutes'], axis=1, inplace=True)

# %%
df.drop(['hours', 'minutes'], axis=1, inplace=True)

# %%
df['duration'] = df['hour']

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df.drop(columns = ["Duration",'hour','min'],inplace = True)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Total_Stops Additional_Info  Price Arrival_Time_hour   duration
# 0    22:20    non-stop         No info   3897          01:10:00   2.833333
# 1    05:50     2 stops         No info   7662          13:15:00   7.416667
# 2    09:25     2 stops         No info  13882          04:25:00  19.000000
# 3    18:05      1 stop         No info   6218          23:30:00   5.416667
# 4    16:50      1 stop         No info  13302          21:35:00   4.750000

# %%
index_df_min = df[df["minutes"] == ''].index

# %%
df.

# %%
# create example DataFrame
df = pd.DataFrame({'hours': [2, 1, 4], 'minutes': [50, 30, 20]})

# combine hours and minutes into a single column
df['hour'
